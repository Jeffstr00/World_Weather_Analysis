# %%
# Import the dependencies.
import pandas as pd
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 743

# %%
# Import the time library and the datetime module from the datetime library.
import time
from datetime import datetime

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
#print(url)

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_desc = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_desc,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hithadhoo
# Processing Record 2 of Set 1 | bowen
# Processing Record 3 of Set 1 | saint-philippe
# Processing Record 4 of Set 1 | caceres
# Processing Record 5 of Set 1 | kapaa
# Processing Record 6 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 7 of Set 1 | grand centre
# City not found. Skipping...
# Processing Record 8 of Set 1 | airai
# Processing Record 9 of Set 1 | huayucachi
# Processing Record 10 of Set 1 | port alfred
# Processing Record 11 of Set 1 | yellowknife
# Processing Record 12 of Set 1 | kharp
# Processing Record 13 of Set 1 | atuona
# Processing Record 14 of Set 1 | north bend
# Processing Record 15 of Set 1 | inongo
# Processing Record 16 of Set 1 | kodiak
# Processing Record 17 of Set 1 | castro
# Processing Record 18 of Set 1 | east london
# Processing Record 19 of Set 1 | the valley
# Processing Record 20 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 21 of Set 1 | lorengau
# Processing Record 22 of Set 1 | te anau
# Processing Record 23 of Set 1 | san jose
# Processing Record 24 of Set 1 | rikitea
# Processing Record 25 of Set 1 | lebu
# Processing Record 26 of Set 1 | allapalli
# Processing Record 27 of Set 1 | dali
# Processing Record 28 of Set 1 | bengkulu
# Processing Record 29 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 30 of Set 1 | mataura
# Processing Record 31 of Set 1 | rocha
# Processing Record 32 of Set 1 | paoua
# Processing Record 33 of Set 1 | sao jose da coroa grande
# Processing Record 34 of Set 1 | arraial do cabo
# Processing Record 35 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 36 of Set 1 | albany
# Processing Record 37 of Set 1 | bethel
# Processing Record 38 of Set 1 | butaritari
# Processing Record 39 of Set 1 | reconquista
# Processing Record 40 of Set 1 | mecca
# Processing Record 41 of Set 1 | cuenca
# Processing Record 42 of Set 1 | hobart
# Processing Record 43 of Set 1 | ushuaia
# Processing Record 44 of Set 1 | dingle
# Processing Record 45 of Set 1 | chapada dos guimaraes
# Processing Record 46 of Set 1 | jamestown
# Processing Record 47 of Set 1 | guerrero negro
# Processing Record 48 of Set 1 | ancud
# Processing Record 49 of Set 1 | victoria
# Processing Record 50 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 1 of Set 2 | nabire
# Processing Record 2 of Set 2 | saint george
# Processing Record 3 of Set 2 | mar del plata
# Processing Record 4 of Set 2 | san buenaventura
# Processing Record 5 of Set 2 | puerto ayora
# Processing Record 6 of Set 2 | goderich
# Processing Record 7 of Set 2 | wattegama
# Processing Record 8 of Set 2 | broome
# Processing Record 9 of Set 2 | narsaq
# Processing Record 10 of Set 2 | nioro
# Processing Record 11 of Set 2 | macomb
# Processing Record 12 of Set 2 | chateauroux
# Processing Record 13 of Set 2 | najran
# Processing Record 14 of Set 2 | bambous virieux
# Processing Record 15 of Set 2 | toliary
# City not found. Skipping...
# Processing Record 16 of Set 2 | makat
# Processing Record 17 of Set 2 | new norfolk
# Processing Record 18 of Set 2 | vaini
# Processing Record 19 of Set 2 | ottersberg
# Processing Record 20 of Set 2 | jabiru
# City not found. Skipping...
# Processing Record 21 of Set 2 | port hedland
# Processing Record 22 of Set 2 | caravelas
# Processing Record 23 of Set 2 | olafsvik
# Processing Record 24 of Set 2 | pontal do parana
# Processing Record 25 of Set 2 | longlac
# City not found. Skipping...
# Processing Record 26 of Set 2 | avarua
# Processing Record 27 of Set 2 | darhan
# Processing Record 28 of Set 2 | dikson
# Processing Record 29 of Set 2 | nanortalik
# Processing Record 30 of Set 2 | grand forks
# Processing Record 31 of Set 2 | salalah
# Processing Record 32 of Set 2 | trelew
# Processing Record 33 of Set 2 | angoram
# Processing Record 34 of Set 2 | yangjiang
# Processing Record 35 of Set 2 | dongsheng
# Processing Record 36 of Set 2 | xam nua
# Processing Record 37 of Set 2 | la ronge
# Processing Record 38 of Set 2 | grindavik
# Processing Record 39 of Set 2 | chokurdakh
# Processing Record 40 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 41 of Set 2 | hounde
# Processing Record 42 of Set 2 | punta arenas
# Processing Record 43 of Set 2 | lasa
# Processing Record 44 of Set 2 | ponta do sol
# Processing Record 45 of Set 2 | lagoa
# Processing Record 46 of Set 2 | barawe
# City not found. Skipping...
# Processing Record 47 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 48 of Set 2 | port hardy
# Processing Record 49 of Set 2 | carballo
# Processing Record 50 of Set 2 | georgetown
# Processing Record 1 of Set 3 | hilo
# Processing Record 2 of Set 3 | bredasdorp
# Processing Record 3 of Set 3 | ballarat
# Processing Record 4 of Set 3 | carnarvon
# Processing Record 5 of Set 3 | tuktoyaktuk
# Processing Record 6 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 7 of Set 3 | busselton
# Processing Record 8 of Set 3 | gusau
# Processing Record 9 of Set 3 | faanui
# Processing Record 10 of Set 3 | cape town
# Processing Record 11 of Set 3 | san quintin
# Processing Record 12 of Set 3 | manicore
# Processing Record 13 of Set 3 | gornozavodsk
# Processing Record 14 of Set 3 | oranjemund
# Processing Record 15 of Set 3 | khatanga
# Processing Record 16 of Set 3 | sassandra
# Processing Record 17 of Set 3 | sitka
# Processing Record 18 of Set 3 | bilibino
# Processing Record 19 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 20 of Set 3 | fairbanks
# Processing Record 21 of Set 3 | hermanus
# Processing Record 22 of Set 3 | tawnat
# City not found. Skipping...
# Processing Record 23 of Set 3 | port elizabeth
# Processing Record 24 of Set 3 | vao
# Processing Record 25 of Set 3 | nishihara
# Processing Record 26 of Set 3 | weymouth
# Processing Record 27 of Set 3 | kavaratti
# Processing Record 28 of Set 3 | anadyr
# Processing Record 29 of Set 3 | constitucion
# Processing Record 30 of Set 3 | gorgan
# Processing Record 31 of Set 3 | chongoyape
# Processing Record 32 of Set 3 | tiksi
# Processing Record 33 of Set 3 | nikolskoye
# Processing Record 34 of Set 3 | shemonaikha
# Processing Record 35 of Set 3 | lavrentiya
# Processing Record 36 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 37 of Set 3 | nueve de julio
# Processing Record 38 of Set 3 | obuasi
# Processing Record 39 of Set 3 | gazanjyk
# Processing Record 40 of Set 3 | upernavik
# Processing Record 41 of Set 3 | sidi ali
# Processing Record 42 of Set 3 | longyearbyen
# Processing Record 43 of Set 3 | limbang
# Processing Record 44 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 45 of Set 3 | sioux lookout
# Processing Record 46 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 47 of Set 3 | concepcion
# Processing Record 48 of Set 3 | dzilam gonzalez
# Processing Record 49 of Set 3 | iskateley
# Processing Record 50 of Set 3 | barrow
# Processing Record 1 of Set 4 | thompson
# Processing Record 2 of Set 4 | solnechnyy
# Processing Record 3 of Set 4 | steinbach
# Processing Record 4 of Set 4 | north myrtle beach
# Processing Record 5 of Set 4 | whitehorse
# Processing Record 6 of Set 4 | vostok
# Processing Record 7 of Set 4 | tautira
# Processing Record 8 of Set 4 | coruripe
# Processing Record 9 of Set 4 | manggar
# Processing Record 10 of Set 4 | yar-sale
# Processing Record 11 of Set 4 | solhan
# Processing Record 12 of Set 4 | eatonton
# Processing Record 13 of Set 4 | walvis bay
# Processing Record 14 of Set 4 | saskylakh
# Processing Record 15 of Set 4 | tasiilaq
# Processing Record 16 of Set 4 | lompoc
# Processing Record 17 of Set 4 | gimli
# Processing Record 18 of Set 4 | ust-tsilma
# Processing Record 19 of Set 4 | svirstroy
# Processing Record 20 of Set 4 | boundiali
# Processing Record 21 of Set 4 | tura
# Processing Record 22 of Set 4 | hasaki
# Processing Record 23 of Set 4 | cherskiy
# Processing Record 24 of Set 4 | kaitangata
# Processing Record 25 of Set 4 | ulladulla
# Processing Record 26 of Set 4 | sibolga
# Processing Record 27 of Set 4 | vestmannaeyjar
# Processing Record 28 of Set 4 | havoysund
# Processing Record 29 of Set 4 | kurtamysh
# Processing Record 30 of Set 4 | murgab
# Processing Record 31 of Set 4 | manokwari
# Processing Record 32 of Set 4 | umm lajj
# Processing Record 33 of Set 4 | chapais
# Processing Record 34 of Set 4 | aklavik
# Processing Record 35 of Set 4 | straumen
# Processing Record 36 of Set 4 | itarema
# Processing Record 37 of Set 4 | adrar
# Processing Record 38 of Set 4 | bud
# Processing Record 39 of Set 4 | bonthe
# Processing Record 40 of Set 4 | mulege
# Processing Record 41 of Set 4 | chiali
# City not found. Skipping...
# Processing Record 42 of Set 4 | sao felix do xingu
# Processing Record 43 of Set 4 | sabang
# Processing Record 44 of Set 4 | henties bay
# Processing Record 45 of Set 4 | ahuimanu
# Processing Record 46 of Set 4 | sukhobezvodnoye
# Processing Record 47 of Set 4 | pangnirtung
# Processing Record 48 of Set 4 | okhotsk
# Processing Record 49 of Set 4 | yerbogachen
# Processing Record 50 of Set 4 | kavieng
# Processing Record 1 of Set 5 | bantogon
# Processing Record 2 of Set 5 | zhitikara
# City not found. Skipping...
# Processing Record 3 of Set 5 | vicuna
# Processing Record 4 of Set 5 | buraydah
# Processing Record 5 of Set 5 | hamburg
# Processing Record 6 of Set 5 | erdenet
# Processing Record 7 of Set 5 | baijiantan
# Processing Record 8 of Set 5 | oktyabrskiy
# Processing Record 9 of Set 5 | chipinge
# Processing Record 10 of Set 5 | sao filipe
# Processing Record 11 of Set 5 | nome
# Processing Record 12 of Set 5 | brookings
# Processing Record 13 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 14 of Set 5 | provideniya
# Processing Record 15 of Set 5 | kenai
# Processing Record 16 of Set 5 | marakkanam
# Processing Record 17 of Set 5 | ixtapa
# Processing Record 18 of Set 5 | husavik
# Processing Record 19 of Set 5 | geraldton
# Processing Record 20 of Set 5 | kuusamo
# Processing Record 21 of Set 5 | mahibadhoo
# Processing Record 22 of Set 5 | sao paulo de olivenca
# Processing Record 23 of Set 5 | kruisfontein
# Processing Record 24 of Set 5 | visby
# Processing Record 25 of Set 5 | cocorit
# Processing Record 26 of Set 5 | batemans bay
# Processing Record 27 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 28 of Set 5 | rabaul
# Processing Record 29 of Set 5 | hofn
# Processing Record 30 of Set 5 | alenquer
# Processing Record 31 of Set 5 | dauphin
# Processing Record 32 of Set 5 | kushmurun
# Processing Record 33 of Set 5 | zhicheng
# Processing Record 34 of Set 5 | portland
# Processing Record 35 of Set 5 | codrington
# Processing Record 36 of Set 5 | maridi
# Processing Record 37 of Set 5 | liverpool
# Processing Record 38 of Set 5 | benjamin aceval
# Processing Record 39 of Set 5 | huarmey
# Processing Record 40 of Set 5 | touros
# Processing Record 41 of Set 5 | linfen
# Processing Record 42 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 43 of Set 5 | veseloyarsk
# Processing Record 44 of Set 5 | port blair
# Processing Record 45 of Set 5 | vila velha
# Processing Record 46 of Set 5 | waipawa
# Processing Record 47 of Set 5 | hami
# Processing Record 48 of Set 5 | tukrah
# Processing Record 49 of Set 5 | kachiry
# Processing Record 50 of Set 5 | mount gambier
# Processing Record 1 of Set 6 | bathsheba
# Processing Record 2 of Set 6 | chuy
# Processing Record 3 of Set 6 | bossembele
# City not found. Skipping...
# Processing Record 4 of Set 6 | mancio lima
# Processing Record 5 of Set 6 | namibe
# Processing Record 6 of Set 6 | acapulco
# Processing Record 7 of Set 6 | kalat
# Processing Record 8 of Set 6 | loandjili
# Processing Record 9 of Set 6 | soe
# Processing Record 10 of Set 6 | seaford
# Processing Record 11 of Set 6 | po
# City not found. Skipping...
# Processing Record 12 of Set 6 | werda
# Processing Record 13 of Set 6 | healdsburg
# Processing Record 14 of Set 6 | rio grande
# Processing Record 15 of Set 6 | matara
# Processing Record 16 of Set 6 | salacgriva
# Processing Record 17 of Set 6 | pisco
# Processing Record 18 of Set 6 | mahasamund
# Processing Record 19 of Set 6 | sananduva
# Processing Record 20 of Set 6 | iqaluit
# Processing Record 21 of Set 6 | kahului
# Processing Record 22 of Set 6 | pevek
# Processing Record 23 of Set 6 | coquimbo
# Processing Record 24 of Set 6 | comodoro rivadavia
# Processing Record 25 of Set 6 | kuching
# Processing Record 26 of Set 6 | kedougou
# Processing Record 27 of Set 6 | luderitz
# Processing Record 28 of Set 6 | cheuskiny
# City not found. Skipping...
# Processing Record 29 of Set 6 | torbay
# Processing Record 30 of Set 6 | qui nhon
# Processing Record 31 of Set 6 | scottsburgh
# City not found. Skipping...
# Processing Record 32 of Set 6 | leningradskiy
# Processing Record 33 of Set 6 | ahipara
# Processing Record 34 of Set 6 | kaifeng
# Processing Record 35 of Set 6 | kokkola
# Processing Record 36 of Set 6 | faya
# Processing Record 37 of Set 6 | rafaela
# Processing Record 38 of Set 6 | talnakh
# Processing Record 39 of Set 6 | eirunepe
# Processing Record 40 of Set 6 | teguldet
# Processing Record 41 of Set 6 | takaka
# Processing Record 42 of Set 6 | helong
# Processing Record 43 of Set 6 | kulhudhuffushi
# Processing Record 44 of Set 6 | ziro
# Processing Record 45 of Set 6 | chauk
# Processing Record 46 of Set 6 | banjar
# Processing Record 47 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 48 of Set 6 | ishigaki
# Processing Record 49 of Set 6 | iisalmi
# Processing Record 50 of Set 6 | talcahuano
# Processing Record 1 of Set 7 | iquique
# Processing Record 2 of Set 7 | chico
# Processing Record 3 of Set 7 | bluff
# Processing Record 4 of Set 7 | blagoveshchensk
# Processing Record 5 of Set 7 | fortuna
# Processing Record 6 of Set 7 | morondava
# Processing Record 7 of Set 7 | groa
# Processing Record 8 of Set 7 | ust-kuyga
# Processing Record 9 of Set 7 | avila
# Processing Record 10 of Set 7 | melfort
# Processing Record 11 of Set 7 | karasjok
# Processing Record 12 of Set 7 | sinnamary
# Processing Record 13 of Set 7 | roma
# Processing Record 14 of Set 7 | karakol
# Processing Record 15 of Set 7 | clyde river
# Processing Record 16 of Set 7 | ilulissat
# Processing Record 17 of Set 7 | tarnogskiy gorodok
# Processing Record 18 of Set 7 | ribeira grande
# Processing Record 19 of Set 7 | kalmunai
# Processing Record 20 of Set 7 | katsuura
# Processing Record 21 of Set 7 | tuatapere
# Processing Record 22 of Set 7 | den helder
# Processing Record 23 of Set 7 | ambilobe
# Processing Record 24 of Set 7 | taltal
# Processing Record 25 of Set 7 | belaya gora
# Processing Record 26 of Set 7 | orlik
# Processing Record 27 of Set 7 | jalu
# Processing Record 28 of Set 7 | qaanaaq
# Processing Record 29 of Set 7 | kollam
# Processing Record 30 of Set 7 | viligili
# City not found. Skipping...
# Processing Record 31 of Set 7 | valparaiso
# Processing Record 32 of Set 7 | verkh-usugli
# Processing Record 33 of Set 7 | zhezkazgan
# Processing Record 34 of Set 7 | wanning
# Processing Record 35 of Set 7 | itapirapua
# Processing Record 36 of Set 7 | marsa matruh
# Processing Record 37 of Set 7 | gat
# Processing Record 38 of Set 7 | dirba
# Processing Record 39 of Set 7 | chengmai
# City not found. Skipping...
# Processing Record 40 of Set 7 | samarai
# Processing Record 41 of Set 7 | novikovo
# Processing Record 42 of Set 7 | avera
# Processing Record 43 of Set 7 | keighley
# Processing Record 44 of Set 7 | awbari
# Processing Record 45 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 46 of Set 7 | teknaf
# Processing Record 47 of Set 7 | vardo
# Processing Record 48 of Set 7 | ashtian
# Processing Record 49 of Set 7 | praia
# Processing Record 50 of Set 7 | dakar
# Processing Record 1 of Set 8 | san juan
# Processing Record 2 of Set 8 | vila franca do campo
# Processing Record 3 of Set 8 | saldanha
# Processing Record 4 of Set 8 | berlevag
# Processing Record 5 of Set 8 | kaka
# Processing Record 6 of Set 8 | starobaltachevo
# Processing Record 7 of Set 8 | manaure
# Processing Record 8 of Set 8 | san vicente
# Processing Record 9 of Set 8 | luchegorsk
# Processing Record 10 of Set 8 | parana
# Processing Record 11 of Set 8 | andenes
# Processing Record 12 of Set 8 | rawannawi
# City not found. Skipping...
# Processing Record 13 of Set 8 | yumen
# Processing Record 14 of Set 8 | dunedin
# Processing Record 15 of Set 8 | svetlogorsk
# Processing Record 16 of Set 8 | ratnagiri
# Processing Record 17 of Set 8 | balclutha
# Processing Record 18 of Set 8 | gari
# Processing Record 19 of Set 8 | esperance
# Processing Record 20 of Set 8 | fort saint john
# City not found. Skipping...
# Processing Record 21 of Set 8 | si satchanalai
# Processing Record 22 of Set 8 | fare
# Processing Record 23 of Set 8 | cabo san lucas
# Processing Record 24 of Set 8 | olean
# Processing Record 25 of Set 8 | mahebourg
# Processing Record 26 of Set 8 | ouesso
# Processing Record 27 of Set 8 | lake charles
# Processing Record 28 of Set 8 | vanimo
# Processing Record 29 of Set 8 | brae
# Processing Record 30 of Set 8 | aksarka
# Processing Record 31 of Set 8 | san andres
# Processing Record 32 of Set 8 | bridlington
# Processing Record 33 of Set 8 | vila do maio
# Processing Record 34 of Set 8 | litoral del san juan
# City not found. Skipping...
# Processing Record 35 of Set 8 | xuddur
# Processing Record 36 of Set 8 | fairlie
# Processing Record 37 of Set 8 | santa vitoria
# Processing Record 38 of Set 8 | agustin codazzi
# Processing Record 39 of Set 8 | brodnica
# Processing Record 40 of Set 8 | korla
# Processing Record 41 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 42 of Set 8 | halifax
# Processing Record 43 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 44 of Set 8 | jiuquan
# Processing Record 45 of Set 8 | sao joao da barra
# Processing Record 46 of Set 8 | kitui
# Processing Record 47 of Set 8 | kapuskasing
# Processing Record 48 of Set 8 | haines junction
# Processing Record 49 of Set 8 | kotido
# Processing Record 50 of Set 8 | nedjo
# Processing Record 1 of Set 9 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 2 of Set 9 | iranshahr
# Processing Record 3 of Set 9 | abu samrah
# Processing Record 4 of Set 9 | kununurra
# Processing Record 5 of Set 9 | stromness
# Processing Record 6 of Set 9 | arman
# Processing Record 7 of Set 9 | belushya guba
# City not found. Skipping...
# Processing Record 8 of Set 9 | sokoni
# Processing Record 9 of Set 9 | ushtobe
# Processing Record 10 of Set 9 | kourou
# Processing Record 11 of Set 9 | luba
# Processing Record 12 of Set 9 | okha
# Processing Record 13 of Set 9 | nantucket
# Processing Record 14 of Set 9 | galesong
# Processing Record 15 of Set 9 | noyabrsk
# Processing Record 16 of Set 9 | pimentel
# Processing Record 17 of Set 9 | coihaique
# Processing Record 18 of Set 9 | wamba
# Processing Record 19 of Set 9 | port lincoln
# Processing Record 20 of Set 9 | cienfuegos
# Processing Record 21 of Set 9 | altadena
# Processing Record 22 of Set 9 | san rafael
# Processing Record 23 of Set 9 | khormuj
# City not found. Skipping...
# Processing Record 24 of Set 9 | asfi
# Processing Record 25 of Set 9 | chernogorsk
# Processing Record 26 of Set 9 | vuktyl
# Processing Record 27 of Set 9 | balkanabat
# Processing Record 28 of Set 9 | jardim
# Processing Record 29 of Set 9 | kudahuvadhoo
# Processing Record 30 of Set 9 | moroni
# Processing Record 31 of Set 9 | bolokhovo
# Processing Record 32 of Set 9 | pauini
# Processing Record 33 of Set 9 | uberlandia
# Processing Record 34 of Set 9 | baymak
# Processing Record 35 of Set 9 | cidreira
# Processing Record 36 of Set 9 | megion
# Processing Record 37 of Set 9 | esmeraldas
# Processing Record 38 of Set 9 | laguna
# Processing Record 39 of Set 9 | mantua
# Processing Record 40 of Set 9 | katangli
# Processing Record 41 of Set 9 | klaksvik
# Processing Record 42 of Set 9 | komyshuvakha
# Processing Record 43 of Set 9 | yepifan
# Processing Record 44 of Set 9 | zhangye
# Processing Record 45 of Set 9 | canby
# Processing Record 46 of Set 9 | wajir
# Processing Record 47 of Set 9 | raymond
# Processing Record 48 of Set 9 | flinders
# Processing Record 49 of Set 9 | larap
# Processing Record 50 of Set 9 | boa vista
# Processing Record 1 of Set 10 | huntsville
# Processing Record 2 of Set 10 | tosham
# Processing Record 3 of Set 10 | ghazipur
# Processing Record 4 of Set 10 | cockeysville
# Processing Record 5 of Set 10 | puerto carreno
# Processing Record 6 of Set 10 | krasnyy chikoy
# Processing Record 7 of Set 10 | kosice
# Processing Record 8 of Set 10 | raga
# Processing Record 9 of Set 10 | gerash
# Processing Record 10 of Set 10 | taunggyi
# Processing Record 11 of Set 10 | srednekolymsk
# Processing Record 12 of Set 10 | bafang
# Processing Record 13 of Set 10 | juneau
# Processing Record 14 of Set 10 | meadow lake
# Processing Record 15 of Set 10 | kupang
# Processing Record 16 of Set 10 | buncrana
# Processing Record 17 of Set 10 | ucluelet
# Processing Record 18 of Set 10 | ust-nera
# Processing Record 19 of Set 10 | sretensk
# Processing Record 20 of Set 10 | qena
# Processing Record 21 of Set 10 | cody
# Processing Record 22 of Set 10 | abilene
# Processing Record 23 of Set 10 | gwanda
# Processing Record 24 of Set 10 | thaba-tseka
# Processing Record 25 of Set 10 | kabinda
# Processing Record 26 of Set 10 | karratha
# Processing Record 27 of Set 10 | luanda
# Processing Record 28 of Set 10 | qasigiannguit
# Processing Record 29 of Set 10 | richards bay
# Processing Record 30 of Set 10 | dzaoudzi
# Processing Record 31 of Set 10 | sao sepe
# Processing Record 32 of Set 10 | akonolinga
# Processing Record 33 of Set 10 | manjacaze
# Processing Record 34 of Set 10 | meckenheim
# Processing Record 35 of Set 10 | baykit
# Processing Record 36 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 37 of Set 10 | coahuayana
# Processing Record 38 of Set 10 | koslan
# Processing Record 39 of Set 10 | ugoofaaru
# Processing Record 40 of Set 10 | pemangkat
# Processing Record 41 of Set 10 | bacolod
# Processing Record 42 of Set 10 | bima
# Processing Record 43 of Set 10 | kishni
# Processing Record 44 of Set 10 | lusambo
# Processing Record 45 of Set 10 | san cristobal
# Processing Record 46 of Set 10 | tual
# Processing Record 47 of Set 10 | yarada
# Processing Record 48 of Set 10 | kungurtug
# Processing Record 49 of Set 10 | tommot
# Processing Record 50 of Set 10 | landerneau
# Processing Record 1 of Set 11 | leshukonskoye
# Processing Record 2 of Set 11 | bilma
# Processing Record 3 of Set 11 | cayenne
# Processing Record 4 of Set 11 | kozhevnikovo
# Processing Record 5 of Set 11 | dagana
# Processing Record 6 of Set 11 | charters towers
# Processing Record 7 of Set 11 | ingham
# Processing Record 8 of Set 11 | scottsbluff
# Processing Record 9 of Set 11 | praia da vitoria
# Processing Record 10 of Set 11 | george
# Processing Record 11 of Set 11 | pangkalanbuun
# Processing Record 12 of Set 11 | viedma
# Processing Record 13 of Set 11 | flin flon
# Processing Record 14 of Set 11 | hailar
# Processing Record 15 of Set 11 | kirakira
# Processing Record 16 of Set 11 | pijijiapan
# Processing Record 17 of Set 11 | andros town
# Processing Record 18 of Set 11 | porto novo
# Processing Record 19 of Set 11 | beringovskiy
# Processing Record 20 of Set 11 | lingao
# Processing Record 21 of Set 11 | kutum
# Processing Record 22 of Set 11 | novopokrovka
# Processing Record 23 of Set 11 | kracheh
# City not found. Skipping...
# Processing Record 24 of Set 11 | listvyanka
# Processing Record 25 of Set 11 | saint-michel-des-saints
# Processing Record 26 of Set 11 | wakkanai
# Processing Record 27 of Set 11 | nongan
# Processing Record 28 of Set 11 | vadso
# Processing Record 29 of Set 11 | aksu
# Processing Record 30 of Set 11 | xining
# Processing Record 31 of Set 11 | polovinnoye
# Processing Record 32 of Set 11 | corvallis
# Processing Record 33 of Set 11 | boyolangu
# Processing Record 34 of Set 11 | tocopilla
# Processing Record 35 of Set 11 | tyukhtet
# Processing Record 36 of Set 11 | miraflores
# Processing Record 37 of Set 11 | kez
# Processing Record 38 of Set 11 | athabasca
# Processing Record 39 of Set 11 | temiscaming
# Processing Record 40 of Set 11 | sile
# Processing Record 41 of Set 11 | lima
# Processing Record 42 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 43 of Set 11 | searcy
# Processing Record 44 of Set 11 | kazalinsk
# City not found. Skipping...
# Processing Record 45 of Set 11 | ebano
# City not found. Skipping...
# Processing Record 46 of Set 11 | samana
# Processing Record 47 of Set 11 | viransehir
# Processing Record 48 of Set 11 | puerto escondido
# Processing Record 49 of Set 11 | savannah bight
# Processing Record 50 of Set 11 | aasiaat
# Processing Record 1 of Set 12 | lotofaga
# Processing Record 2 of Set 12 | ulaangom
# Processing Record 3 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 4 of Set 12 | matamoros
# Processing Record 5 of Set 12 | santo angelo
# Processing Record 6 of Set 12 | rapar
# Processing Record 7 of Set 12 | trairi
# Processing Record 8 of Set 12 | tessalit
# Processing Record 9 of Set 12 | khovu-aksy
# Processing Record 10 of Set 12 | kathu
# Processing Record 11 of Set 12 | oistins
# Processing Record 12 of Set 12 | taft
# Processing Record 13 of Set 12 | norman wells
# Processing Record 14 of Set 12 | labuhan
# Processing Record 15 of Set 12 | uhlove
# Processing Record 16 of Set 12 | skovorodino
# Processing Record 17 of Set 12 | hoi an
# Processing Record 18 of Set 12 | riyaq
# City not found. Skipping...
# Processing Record 19 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 20 of Set 12 | karachev
# Processing Record 21 of Set 12 | ruatoria
# City not found. Skipping...
# Processing Record 22 of Set 12 | aarschot
# Processing Record 23 of Set 12 | buchanan
# Processing Record 24 of Set 12 | havre-saint-pierre
# Processing Record 25 of Set 12 | kurumkan
# Processing Record 26 of Set 12 | port macquarie
# Processing Record 27 of Set 12 | souillac
# Processing Record 28 of Set 12 | nyurba
# Processing Record 29 of Set 12 | campina grande do sul
# Processing Record 30 of Set 12 | sept-iles
# Processing Record 31 of Set 12 | tempio pausania
# Processing Record 32 of Set 12 | tomatlan
# Processing Record 33 of Set 12 | komsomolskiy
# Processing Record 34 of Set 12 | riyadh
# Processing Record 35 of Set 12 | leh
# Processing Record 36 of Set 12 | tungkang
# City not found. Skipping...
# Processing Record 37 of Set 12 | muroran
# Processing Record 38 of Set 12 | alanya
# Processing Record 39 of Set 12 | juybar
# Processing Record 40 of Set 12 | miri
# Processing Record 41 of Set 12 | victor harbor
# Processing Record 42 of Set 12 | margate
# Processing Record 43 of Set 12 | lincoln
# Processing Record 44 of Set 12 | denpasar
# Processing Record 45 of Set 12 | tanout
# Processing Record 46 of Set 12 | hualmay
# Processing Record 47 of Set 12 | sisophon
# Processing Record 48 of Set 12 | usinsk
# Processing Record 49 of Set 12 | duluth
# Processing Record 50 of Set 12 | saint-francois
# Processing Record 1 of Set 13 | grimari
# City not found. Skipping...
# Processing Record 2 of Set 13 | mocuba
# Processing Record 3 of Set 13 | devonport
# Processing Record 4 of Set 13 | san ignacio
# Processing Record 5 of Set 13 | alice springs
# Processing Record 6 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 7 of Set 13 | jaisalmer
# Processing Record 8 of Set 13 | bajil
# Processing Record 9 of Set 13 | mexico
# Processing Record 10 of Set 13 | hornepayne
# Processing Record 11 of Set 13 | peleduy
# Processing Record 12 of Set 13 | bam
# Processing Record 13 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 14 of Set 13 | plastun
# Processing Record 15 of Set 13 | villamontes
# Processing Record 16 of Set 13 | conde
# Processing Record 17 of Set 13 | san pedro
# Processing Record 18 of Set 13 | lai
# Processing Record 19 of Set 13 | guane
# Processing Record 20 of Set 13 | ajdabiya
# Processing Record 21 of Set 13 | kitgum
# Processing Record 22 of Set 13 | quatre cocos
# Processing Record 23 of Set 13 | milton
# Processing Record 24 of Set 13 | teya
# Processing Record 25 of Set 13 | danilov
# Processing Record 26 of Set 13 | ossora
# Processing Record 27 of Set 13 | coxim
# Processing Record 28 of Set 13 | belawan
# Processing Record 29 of Set 13 | escarcega
# Processing Record 30 of Set 13 | almora
# Processing Record 31 of Set 13 | ciudad real
# Processing Record 32 of Set 13 | fort nelson
# Processing Record 33 of Set 13 | callaway
# Processing Record 34 of Set 13 | makakilo city
# Processing Record 35 of Set 13 | hof
# Processing Record 36 of Set 13 | zhigansk
# Processing Record 37 of Set 13 | la paz
# Processing Record 38 of Set 13 | poya
# Processing Record 39 of Set 13 | monterey
# Processing Record 40 of Set 13 | aykhal
# Processing Record 41 of Set 13 | abha
# Processing Record 42 of Set 13 | januaria
# Processing Record 43 of Set 13 | nandyal
# Processing Record 44 of Set 13 | asayita
# City not found. Skipping...
# Processing Record 45 of Set 13 | yaan
# Processing Record 46 of Set 13 | san lorenzo
# Processing Record 47 of Set 13 | acajutla
# Processing Record 48 of Set 13 | cozumel
# Processing Record 49 of Set 13 | puerto madryn
# Processing Record 50 of Set 13 | senador jose porfirio
# Processing Record 1 of Set 14 | kokopo
# Processing Record 2 of Set 14 | kholodnyy
# Processing Record 3 of Set 14 | anaconda
# Processing Record 4 of Set 14 | pitimbu
# Processing Record 5 of Set 14 | galashki
# Processing Record 6 of Set 14 | veshenskaya
# Processing Record 7 of Set 14 | porbandar
# Processing Record 8 of Set 14 | dudinka
# Processing Record 9 of Set 14 | namatanai
# Processing Record 10 of Set 14 | togur
# Processing Record 11 of Set 14 | krasnogorsk
# Processing Record 12 of Set 14 | palimbang
# Processing Record 13 of Set 14 | formoso do araguaia
# City not found. Skipping...
# Processing Record 14 of Set 14 | nicoya
# Processing Record 15 of Set 14 | mandurah
# Processing Record 16 of Set 14 | le port
# Processing Record 17 of Set 14 | cabedelo
# Processing Record 18 of Set 14 | srandakan
# Processing Record 19 of Set 14 | katsiveli
# City not found. Skipping...
# Processing Record 20 of Set 14 | goiatuba
# Processing Record 21 of Set 14 | tiarei
# Processing Record 22 of Set 14 | nalut
# Processing Record 23 of Set 14 | khuzdar
# Processing Record 24 of Set 14 | kidal
# Processing Record 25 of Set 14 | sweetwater
# Processing Record 26 of Set 14 | sur
# Processing Record 27 of Set 14 | ostrovnoy
# Processing Record 28 of Set 14 | cameron park
# Processing Record 29 of Set 14 | palatka
# Processing Record 30 of Set 14 | progreso
# Processing Record 31 of Set 14 | mastic beach
# Processing Record 32 of Set 14 | sembakung
# Processing Record 33 of Set 14 | santa cruz
# Processing Record 34 of Set 14 | muros
# Processing Record 35 of Set 14 | tambura
# Processing Record 36 of Set 14 | onega
# Processing Record 37 of Set 14 | kayerkan
# Processing Record 38 of Set 14 | la gaulette
# City not found. Skipping...
# Processing Record 39 of Set 14 | oriximina
# Processing Record 40 of Set 14 | lata
# Processing Record 41 of Set 14 | ibanda
# Processing Record 42 of Set 14 | saleaula
# City not found. Skipping...
# Processing Record 43 of Set 14 | agadez
# Processing Record 44 of Set 14 | rock sound
# Processing Record 45 of Set 14 | sansai
# City not found. Skipping...
# Processing Record 46 of Set 14 | urengoy
# Processing Record 47 of Set 14 | kurilsk
# Processing Record 48 of Set 14 | edeia
# Processing Record 49 of Set 14 | kendari
# Processing Record 50 of Set 14 | banmo
# City not found. Skipping...
# Processing Record 1 of Set 15 | waingapu
# Processing Record 2 of Set 15 | yatou
# Processing Record 3 of Set 15 | daru
# Processing Record 4 of Set 15 | hazorasp
# Processing Record 5 of Set 15 | tumen
# Processing Record 6 of Set 15 | high level
# Processing Record 7 of Set 15 | haizhou
# Processing Record 8 of Set 15 | kikwit
# Processing Record 9 of Set 15 | biltine
# Processing Record 10 of Set 15 | iracoubo
# Processing Record 11 of Set 15 | along
# Processing Record 12 of Set 15 | yeniseysk
# Processing Record 13 of Set 15 | emerald
# Processing Record 14 of Set 15 | tibati
# Processing Record 15 of Set 15 | gornopravdinsk
# Processing Record 16 of Set 15 | kirensk
# Processing Record 17 of Set 15 | kindu
# Processing Record 18 of Set 15 | gorey
# Processing Record 19 of Set 15 | pogoanele
# Processing Record 20 of Set 15 | macamic
# Processing Record 21 of Set 15 | saint-ambroise
# Processing Record 22 of Set 15 | clonakilty
# Processing Record 23 of Set 15 | kalamare
# Processing Record 24 of Set 15 | darnah
# Processing Record 25 of Set 15 | west plains
# Processing Record 26 of Set 15 | yanan
# City not found. Skipping...
# Processing Record 27 of Set 15 | svetlyy
# Processing Record 28 of Set 15 | atocha
# Processing Record 29 of Set 15 | college
# Processing Record 30 of Set 15 | sabya
# Processing Record 31 of Set 15 | pacific grove
# Processing Record 32 of Set 15 | cockburn town
# Processing Record 33 of Set 15 | churapcha
# Processing Record 34 of Set 15 | taksimo
# Processing Record 35 of Set 15 | dolgoye
# Processing Record 36 of Set 15 | elko
# Processing Record 37 of Set 15 | santa lucia
# Processing Record 38 of Set 15 | riberalta
# Processing Record 39 of Set 15 | prabumulih
# Processing Record 40 of Set 15 | bacungan
# Processing Record 41 of Set 15 | kaeo
# Processing Record 42 of Set 15 | eyl
# Processing Record 43 of Set 15 | sokoto
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 684

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Hithadhoo  -0.6000   73.0833     80.24        65          60
# 1           Bowen -20.0167  148.2333     80.82        73          36
# 2  Saint-Philippe -21.3585   55.7679     74.79        74           8
# 3         Caceres  39.5220   -6.3748     42.80        41           0
# 4           Kapaa  22.0752 -159.3190     81.12        71           7
# 5           Airai  -8.9266  125.4092     62.82        87         100
# 6      Huayucachi -12.1333  -75.2333     49.39        92         100
# 7     Port Alfred -33.5906   26.8910     66.16        80          17
# 8     Yellowknife  62.4560 -114.3525      0.41        88          75
# 9           Kharp  66.8014   65.8081      6.24        91         100
#
#    Wind Speed   Current Description Country                 Date
# 0        7.00         broken clouds      MV  2022-01-28 22:56:03
# 1       17.92      scattered clouds      AU  2022-01-28 22:56:04
# 2        5.68             clear sky      RE  2022-01-28 22:56:04
# 3        8.68             clear sky      ES  2022-01-28 22:56:04
# 4        1.99             clear sky      US  2022-01-28 22:56:04
# 5        3.33       overcast clouds      TL  2022-01-28 22:56:05
# 6        0.38  heavy intensity rain      PE  2022-01-28 22:56:05
# 7        9.26            light rain      ZA  2022-01-28 22:56:05
# 8       11.50            light snow      CA  2022-01-28 22:51:44
# 9        5.35       overcast clouds      RU  2022-01-28 22:56:06

# %%
new_column_order = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Hithadhoo      MV  -0.6000   73.0833     80.24        65          60
# 1           Bowen      AU -20.0167  148.2333     80.82        73          36
# 2  Saint-Philippe      RE -21.3585   55.7679     74.79        74           8
# 3         Caceres      ES  39.5220   -6.3748     42.80        41           0
# 4           Kapaa      US  22.0752 -159.3190     81.12        71           7
#
#    Wind Speed Current Description
# 0        7.00       broken clouds
# 1       17.92    scattered clouds
# 2        5.68           clear sky
# 3        8.68           clear sky
# 4        1.99           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
